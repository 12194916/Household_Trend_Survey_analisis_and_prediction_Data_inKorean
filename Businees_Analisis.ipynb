# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn

# %%
df=pd.read_csv("가계동향조사-2010-2021.csv",low_memory=False)
df.head()
# Out:
#    조사연도  조사분기  가구일련번호    가구구분코드  가구원수  노인가구여부  모자가구여부  맞벌이가구여부  일반가구여부  \
# 0  2019     1       1  근로자 외 가구     1       0       0        0       1
# 1  2019     1       2    근로자 가구     3       0       0        0       1
# 2  2019     1       3  근로자 외 가구     1       0       0        0       1
# 3  2019     1       4    근로자 가구     3       0       0        0       1
# 4  2019     1       5    근로자 가구     2       0       0        0       1
#
#    세대구분코드  ...  가계지출_소비지출_기타상품서비스이용금액  가계지출_비소비지출금액  가계지출_비소비지출_경상조세  \
# 0     1.0  ...                  79471        177713                0
# 1     2.0  ...                 279948        247983            17607
# 2     1.0  ...                  24264          3333                0
# 3     2.0  ...                 131791        470963           101583
# 4     2.0  ...                1653948        437987            20837
#
#   가계지출_비소비지출_비경상조세  가계지출_비소비지출_연금기여금  가계지출_비소비지출_사회보험료 가계지출_비소비지출_이자비용  \
# ...

# %%
print(df.isnull().sum())
print(len(df.isnull()))
# Out:
# 조사연도                           0
# 조사분기                           0
# 가구일련번호                         0
# 가구구분코드                         0
# 가구원수                           0
# 노인가구여부                         0
# 모자가구여부                         0
# 맞벌이가구여부                        0
# 일반가구여부                         0
# 세대구분코드                        84
# 배우자코드                          0
# 가구주_성별코드                       0
# 가구주_연령                         0
# 가구주_학력코드                       0
# 가구주_수학구분코드                    10
# 가구주_취업여부                       0
# 가구주_10차산업분류코드                  0
# 가구주_7차직업분류코드                   0
# 가구주_종사상지위코드                20511
# 거처구분코드                         0
# 자동차보유대수                        0
# 입주형태코드                         0
# 주택소유유무                         0
# 가중값                            0
# 소득                             0
# 소득_경상소득                        0
# 소득_경상소득_근로소득                   0
# 소득_경상소득_사업소득                   0
# ...

# %%
df.columns
# Out:
# Index(['조사연도', '조사분기', '가구일련번호', '가구구분코드', '가구원수', '노인가구여부', '모자가구여부',
#        '맞벌이가구여부', '일반가구여부', '세대구분코드', '배우자코드', '가구주_성별코드', '가구주_연령',
#        '가구주_학력코드', '가구주_수학구분코드', '가구주_취업여부', '가구주_10차산업분류코드', '가구주_7차직업분류코드',
#        '가구주_종사상지위코드', '거처구분코드', '자동차보유대수', '입주형태코드', '주택소유유무', '가중값', '소득',
#        '소득_경상소득', '소득_경상소득_근로소득', '소득_경상소득_사업소득', '소득_경상소득_재산소득',
#        '소득_경상소득_이전소득', '소득_비경상소득', '가계지출금액', '가계지출_소비지출금액',
#        '가계지출_소비지출_식료품비주류음료구입비', '가계지출_소비지출_주류담배구입비', '가계지출_소비지출_의류신발구입비',
#        '가계지출_소비지출_주거수도광열비', '가계지출_소비지출_가정용품가사서비스이용금액', '가계지출_소비지출_보건제품구입비',
#        '가계지출_소비지출_교통비', '가계지출_소비지출_통신비', '가계지출_소비지출_오락문화비', '가계지출_소비지출_교육비',
#        '가계지출_소비지출_음식숙박비', '가계지출_소비지출_기타상품서비스이용금액', '가계지출_비소비지출금액',
#        '가계지출_비소비지출_경상조세', '가계지출_비소비지출_비경상조세', '가계지출_비소비지출_연금기여금',
#        '가계지출_비소비지출_사회보험료', '가계지출_비소비지출_이자비용', '가계지출_비소비지출_가구간이전지출금액',
#        '가계지출_비소비지출_비영리단체이전지출금액', '연령대'],
#       dtype='object')

# %%
null_counts = df.isnull().sum()

# %%
for col in df.columns:
    if null_counts[col] > len(df_1) * 0.5:
        df.drop(col, axis=1, inplace=True)
    else:
      mask = df[col].isnull()
      non_nan_values = df.loc[~mask, col]
      sampled_values = np.random.choice(non_nan_values, size=mask.sum(), replace=True)
      df.loc[mask, col] = sampled_values

# %%
df.isnull().any()
# Out:
# 조사연도                       False
# 조사분기                       False
# 가구일련번호                     False
# 가구구분코드                     False
# 가구원수                       False
# 노인가구여부                     False
# 모자가구여부                     False
# 맞벌이가구여부                    False
# 일반가구여부                     False
# 세대구분코드                     False
# 배우자코드                      False
# 가구주_성별코드                   False
# 가구주_연령                     False
# 가구주_학력코드                   False
# 가구주_수학구분코드                 False
# 가구주_취업여부                   False
# 가구주_10차산업분류코드              False
# 가구주_7차직업분류코드               False
# 가구주_종사상지위코드                False
# 거처구분코드                     False
# 자동차보유대수                    False
# 입주형태코드                     False
# 주택소유유무                     False
# 가중값                        False
# 소득                         False
# 소득_경상소득                    False
# 소득_경상소득_근로소득               False
# 소득_경상소득_사업소득               False
# ...

# %%
str_cols = df.select_dtypes(include=['object']).columns.tolist()

if str_cols:
    print(str_cols)
else:
    print("No columns contain string variables.")
# Out:
# ['가구구분코드', '가구주_학력코드', '가구주_10차산업분류코드', '가구주_7차직업분류코드', '가구주_종사상지위코드', '거처구분코드', '입주형태코드']

# %%
str_df = df[str_cols]
str_df.head()
# Out:
#      가구구분코드 가구주_학력코드 가구주_10차산업분류코드 가구주_7차직업분류코드 가구주_종사상지위코드    거처구분코드 입주형태코드
# 0  근로자 외 가구      대학4             Z         기타무직        임시근로  단독-다가구주택     전세
# 1    근로자 가구       고등             L         단순노무        임시근로  단독-다가구주택  보증부월세
# 2  근로자 외 가구      대학4             Z         기타무직        상용근로  단독-다가구주택  보증부월세
# 3    근로자 가구      대학4             O           사무        상용근로  단독-다가구주택     전세
# 4    근로자 가구       중학             Q          서비스        상용근로  단독-다가구주택  보증부월세

# %%
df.head()
# Out:
#    조사연도  조사분기  가구일련번호    가구구분코드  가구원수  노인가구여부  모자가구여부  맞벌이가구여부  일반가구여부  \
# 0  2019     1       1  근로자 외 가구     1       0       0        0       1
# 1  2019     1       2    근로자 가구     3       0       0        0       1
# 2  2019     1       3  근로자 외 가구     1       0       0        0       1
# 3  2019     1       4    근로자 가구     3       0       0        0       1
# 4  2019     1       5    근로자 가구     2       0       0        0       1
#
#    세대구분코드  ...  가계지출_소비지출_기타상품서비스이용금액  가계지출_비소비지출금액  가계지출_비소비지출_경상조세  \
# 0     1.0  ...                  79471        177713                0
# 1     2.0  ...                 279948        247983            17607
# 2     1.0  ...                  24264          3333                0
# 3     2.0  ...                 131791        470963           101583
# 4     2.0  ...                1653948        437987            20837
#
#   가계지출_비소비지출_비경상조세  가계지출_비소비지출_연금기여금  가계지출_비소비지출_사회보험료 가계지출_비소비지출_이자비용  \
# ...

# %%
df['연령대'].value_counts()
# Out:
# 5     21036
# 4     18684
# 6     18403
# 3     12834
# 7     11925
# 8      4844
# 2      4513
# 9       262
# 1        98
# 10        7
# Name: 연령대, dtype: int64

# %%
import matplotlib.font_manager as fm
f = [f.name for f in fm.fontManager.ttflist]
print(f)

# 확인 이후
plt.rc('font', family='Malgun Gothic')
# Out:
# ['DejaVu Sans Display', 'STIXNonUnicode', 'STIXGeneral', 'DejaVu Sans', 'cmss10', 'STIXGeneral', 'DejaVu Serif Display', 'cmsy10', 'STIXSizeOneSym', 'DejaVu Serif', 'STIXSizeFourSym', 'DejaVu Sans Mono', 'DejaVu Sans', 'STIXSizeTwoSym', 'DejaVu Serif', 'cmb10', 'DejaVu Sans', 'STIXNonUnicode', 'DejaVu Sans Mono', 'DejaVu Sans', 'cmex10', 'STIXGeneral', 'STIXSizeFourSym', 'STIXNonUnicode', 'cmtt10', 'cmr10', 'DejaVu Serif', 'DejaVu Sans Mono', 'STIXNonUnicode', 'STIXSizeTwoSym', 'STIXSizeThreeSym', 'cmmi10', 'DejaVu Sans Mono', 'STIXGeneral', 'STIXSizeOneSym', 'DejaVu Serif', 'STIXSizeThreeSym', 'STIXSizeFiveSym', 'Microsoft Himalaya', 'Segoe Print', 'Sitka Small', 'Segoe MDL2 Assets', 'Segoe UI Symbol', 'Verdana', 'Lucida Sans Unicode', 'Segoe Script', 'Yu Gothic', 'Calibri', 'Segoe UI', 'Segoe UI', 'Sitka Small', 'Corbel', 'MS Gothic', 'Microsoft Tai Le', 'Franklin Gothic Medium', 'Marlett', 'Cambria', 'SimSun', 'Microsoft YaHei', 'Microsoft YaHei', 'Arial', 'Verdana', 'Georgia', 'L
# ...

# %%
for col in df.columns:
    if df[col].dtype != 'object':  
        plt.figure(figsize=(8,8))
        sns.boxplot(data=df, x=col, color='lightblue')
        plt.title(f'Boxplot of {col}')
        plt.rc('axes', unicode_minus=False)
        plt.show()

# %%
for col in df.columns:
    if df[col].dtype != 'object':
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        df = df.drop(index=df[(df[col] < lower_bound) | (df[col] > upper_bound)].index)

# %%
df.head()
# Out:
#      조사연도  조사분기  가구일련번호    가구구분코드  가구원수  노인가구여부  모자가구여부  맞벌이가구여부  일반가구여부  \
# 15   2019     1      16  근로자 외 가구     1       0       0        0       1
# 47   2019     1      48    근로자 가구     1       0       0        0       1
# 79   2019     1      80  근로자 외 가구     1       0       0        0       1
# 89   2019     1      90  근로자 외 가구     4       0       0        0       1
# 160  2019     1     161    근로자 가구     1       0       0        0       1
#
#      세대구분코드  ...  가계지출_소비지출_기타상품서비스이용금액  가계지출_비소비지출금액  가계지출_비소비지출_경상조세  \
# 15      1.0  ...                  32838        234540                0
# 47      1.0  ...                  17267        185020            17720
# 79      1.0  ...                  11282         15000                0
# 89      2.0  ...                 287557        408400                0
# 160     1.0  ...                  74881         76667                0
#
#     가계지출_비소비지출_비경상조세  가계지출_비소비지출_연금기여금  가계지출_비소비지출_사회보험료 가계지출_비소비지출_이자비용  \
# ...

# %%
for i in str_df.columns:
  plt.figure(figsize=(10,14))
  sns.countplot(data=df, x=i, hue='연령대')
  plt.title(f'Count Plot of {i} with 연령대 as Hue')
  plt.show()
  plt.figure(figsize=(10,14))
  df.groupby(i)['연령대'].mean().plot(kind='bar')
  plt.title(f'Bar Plot of Mean Label Column by {i}')
  plt.show()

# %%
print(df.describe())
# Out:
#               조사연도         조사분기       가구일련번호         가구원수  노인가구여부  모자가구여부  \
# count  4264.000000  4264.000000  4264.000000  4264.000000  4264.0  4264.0
# mean   2020.087242     2.573171  3145.016651     1.969278     0.0     0.0
# std       0.793704     1.111133  1779.291387     0.973611     0.0     0.0
# min    2019.000000     1.000000     1.000000     1.000000     0.0     0.0
# 25%    2019.000000     2.000000  1579.000000     1.000000     0.0     0.0
# 50%    2020.000000     3.000000  3180.000000     2.000000     0.0     0.0
# 75%    2021.000000     4.000000  4623.250000     2.000000     0.0     0.0
# max    2021.000000     4.000000  6533.000000     6.000000     0.0     0.0
#
#            맞벌이가구여부       일반가구여부       세대구분코드        배우자코드  ...  \
# count  4264.000000  4264.000000  4264.000000  4264.000000  ...
# mean      0.266417     0.733583     1.356942     1.983349  ...
# std       0.442136     0.442136     0.524943     0.990669  ...
# ...

# %%
df.head()
# Out:
#      조사연도  조사분기  가구일련번호    가구구분코드  가구원수  노인가구여부  모자가구여부  맞벌이가구여부  일반가구여부  \
# 15   2019     1      16  근로자 외 가구     1       0       0        0       1
# 47   2019     1      48    근로자 가구     1       0       0        0       1
# 79   2019     1      80  근로자 외 가구     1       0       0        0       1
# 89   2019     1      90  근로자 외 가구     4       0       0        0       1
# 160  2019     1     161    근로자 가구     1       0       0        0       1
#
#      세대구분코드  ...  가계지출_소비지출_기타상품서비스이용금액  가계지출_비소비지출금액  가계지출_비소비지출_경상조세  \
# 15      1.0  ...                  32838        234540                0
# 47      1.0  ...                  17267        185020            17720
# 79      1.0  ...                  11282         15000                0
# 89      2.0  ...                 287557        408400                0
# 160     1.0  ...                  74881         76667                0
#
#     가계지출_비소비지출_비경상조세  가계지출_비소비지출_연금기여금  가계지출_비소비지출_사회보험료 가계지출_비소비지출_이자비용  \
# ...

# %%
plt.figure(figsize=(15,18))
sns.scatterplot(data=df,x="가계지출_소비지출_기타상품서비스이용금액", y="가계지출_비소비지출금액", hue='조사연도',s=100,palette='bright')
plt.show()

plt.figure(figsize=(15,18))
sns.scatterplot(data=df,x="가계지출_비소비지출_비영리단체이전지출금액", y="가계지출_비소비지출_가구간이전지출금액", hue='조사연도',s=100,palette='bright')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
for i in str_cols:
  df[i]=lb.fit_transform(df[i])

# %%
df.dtypes
# Out:
# 조사연도                         int64
# 조사분기                         int64
# 가구일련번호                       int64
# 가구구분코드                       int32
# 가구원수                         int64
# 노인가구여부                       int64
# 모자가구여부                       int64
# 맞벌이가구여부                      int64
# 일반가구여부                       int64
# 세대구분코드                     float64
# 배우자코드                        int64
# 가구주_성별코드                     int64
# 가구주_연령                       int64
# 가구주_학력코드                     int32
# 가구주_수학구분코드                 float64
# 가구주_취업여부                     int64
# 가구주_10차산업분류코드                int32
# 가구주_7차직업분류코드                 int32
# 가구주_종사상지위코드                  int32
# 거처구분코드                       int32
# 자동차보유대수                      int64
# 입주형태코드                       int32
# 주택소유유무                       int64
# 가중값                        float64
# 소득                           int64
# 소득_경상소득                      int64
# 소득_경상소득_근로소득                 int64
# ...

# %%
# sns.pairplot(df) 
# plt.show()

# %%
corr=df.corrwith(df['연령대']).abs().sort_values(ascending=False)
corr
# Out:
# 연령대                        1.000000
# 가구주_연령                     0.979001
# 배우자코드                      0.412867
# 주택소유유무                     0.407633
# 소득_경상소득_이전소득               0.347597
# 가계지출_비소비지출_연금기여금           0.329702
# 가계지출_소비지출_식료품비주류음료구입비      0.321942
# 가계지출_소비지출_음식숙박비            0.318215
# 가구주_학력코드                   0.313768
# 맞벌이가구여부                    0.303615
# 일반가구여부                     0.303615
# 가구구분코드                     0.298165
# 소득_경상소득_근로소득               0.244057
# 가계지출_소비지출_오락문화비            0.240532
# 가구주_7차직업분류코드               0.217967
# 가구주_종사상지위코드                0.201515
# 가계지출_소비지출_주거수도광열비          0.195357
# 가계지출_소비지출_보건제품구입비          0.194633
# 가중값                        0.190142
# 가구원수                       0.188927
# 입주형태코드                     0.176560
# 소득_경상소득_사업소득               0.171572
# 가계지출_비소비지출_사회보험료           0.167920
# 가계지출_비소비지출금액               0.165095
# 가계지출_비소비지출_경상조세            0.153088
# 가계지출_비소비지출_비영리단체이전지출금액     0.137950
# ...

# %%
df = df.drop(columns=corr[corr < 0.15].index)

# %%
corrm=df.corr().abs()
plt.figure(figsize=(30,30))
sns.heatmap(corrm, cmap="coolwarm", annot=True)
plt.plot()
plt.show()

# %%
X=df.drop('연령대',axis=1)
Y=df['연령대'].copy()

# %%
from sklearn.feature_selection import mutual_info_classif
mutual_info = mutual_info_classif(X, Y)
mutual_info
# Out:
# array([0.06273318, 0.1421764 , 0.        , 0.        , 0.05069476,
#        0.03674978, 0.1186966 , 0.        , 1.65878317, 0.21122096,
#        0.02861166, 0.02203714, 0.14013804, 0.09096029, 0.12133648,
#        0.12132849, 0.12516908, 0.1230835 , 0.07578096, 0.        ,
#        0.15413573, 0.        , 0.07973135, 0.03177144, 0.04259454,
#        0.05576309, 0.07602576, 0.07334612, 0.07845387, 0.01890553,
#        0.25427948, 0.21181989])

# %%
mutual_info = pd.Series(mutual_info) 
mutual_info.index = X.columns
milist=mutual_info.sort_values(ascending=False)
milist
# Out:
# 가구주_연령                   1.658783
# 가계지출_비소비지출_연금기여금         0.254279
# 가계지출_비소비지출_사회보험료         0.211820
# 가구주_학력코드                 0.211221
# 소득_경상소득_이전소득             0.154136
# 가구원수                     0.142176
# 가구주_7차직업분류코드             0.140138
# 가중값                      0.125169
# 소득_경상소득_근로소득             0.123084
# 입주형태코드                   0.121336
# 주택소유유무                   0.121328
# 배우자코드                    0.118697
# 가구주_종사상지위코드              0.090960
# 가계지출_소비지출_식료품비주류음료구입비    0.079731
# 가계지출_비소비지출_경상조세          0.078454
# 가계지출_소비지출_음식숙박비          0.076026
# 소득_경상소득_사업소득             0.075781
# 가계지출_비소비지출금액             0.073346
# 가구구분코드                   0.062733
# 가계지출_소비지출_오락문화비          0.055763
# 맞벌이가구여부                  0.050695
# 가계지출_소비지출_보건제품구입비        0.042595
# 일반가구여부                   0.036750
# 가계지출_소비지출_주거수도광열비        0.031771
# 가구주_수학구분코드               0.028612
# 가구주_취업여부                 0.022037
# 가계지출_비소비지출_비경상조세         0.018906
# ...

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20, 8))
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X=sc.fit_transform(X)
X
# Out:
# array([[ 1.4755837 , -0.99566606,  0.        , ...,  0.        ,
#         -1.0035996 , -1.15553584],
#        [-0.67769792, -0.99566606,  0.        , ...,  0.        ,
#         -1.0035996 , -1.07819501],
#        [ 1.4755837 , -0.99566606,  0.        , ...,  0.        ,
#         -1.0035996 , -1.11201324],
#        ...,
#        [ 1.4755837 ,  1.05878354,  0.        , ...,  0.        ,
#         -1.0035996 ,  0.48332532],
#        [ 1.4755837 , -0.99566606,  0.        , ...,  0.        ,
#         -1.0035996 , -1.00394192],
#        [-0.67769792, -0.99566606,  0.        , ...,  0.        ,
#          0.21078771,  0.11000139]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,random_state=42,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
LR_model = LinearRegression()
LR_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn import metrics
def evaluation(model):
  score = model.score(x_test, y_test)
  y_predicted=model.predict(x_test)
  mse=metrics.mean_squared_error(y_test,y_predicted)
  mae=metrics.mean_absolute_error(y_test,y_predicted)
  print("Mean Squared error: ", mse)
  print("Mean Absolute error: ", mae)
evaluation(LR_model)
# Out:
# Mean Squared error:  0.08194188049625653
# Mean Absolute error:  0.24622956425600195

# %%
from sklearn import tree
f1 = []
for k in range(2,50):
    dt = tree.DecisionTreeClassifier(max_leaf_nodes=k)
    dt.fit(x_train, y_train)
    y_predict = dt.predict(x_test)
    f1.append(metrics.mean_squared_error(y_test, y_predict))

plt.figure(figsize=(10,6))
plt.plot(range(2,50),f1)
plt.xticks(range(2,50))
plt.grid()
plt.show()

f1 = []
for k in range(1,50):
    dt = tree.DecisionTreeClassifier(max_depth=k)
    dt.fit(x_train, y_train)
    y_predict = dt.predict(x_test)
    f1.append(metrics.mean_squared_error(y_test, y_predict))

plt.figure(figsize=(10,6))
plt.plot(range(1,50),f1)
plt.xticks(range(1,50))
plt.grid()
plt.show()

# %%
from sklearn import tree
DT_model = tree.DecisionTreeClassifier(max_leaf_nodes=6,max_depth=4)
DT_model = DT_model.fit(x_train, y_train)

# %%
evaluation(DT_model)
# Out:
# Mean Squared error:  0.0035169988276670576
# Mean Absolute error:  0.0035169988276670576

# %%
from sklearn.linear_model import LogisticRegression
LgR_model=LogisticRegression(max_iter=2500)
LgR_model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=2500)

# %%
evaluation(LR_model)
# Out:
# Mean Squared error:  0.08194188049625653
# Mean Absolute error:  0.24622956425600195

# %%
import pickle
filename = 'saved_model_decision_tree.pkl'
with open(filename, 'wb') as file:
    pickle.dump(DT_model, file)
